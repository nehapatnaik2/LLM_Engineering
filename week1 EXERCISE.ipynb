# %% [markdown]
# # End of week 1 exercise
#
# To demonstrate your familiarity with OpenAI API, and also Ollama, build a tool that takes a technical question,
# and responds with an explanation. This is a tool that you will be able to use yourself during the course!

# %%
# imports
import os
import json
from dotenv import load_dotenv
from IPython.display import Markdown, display, update_display
from openai import OpenAI

# %%
# constants

MODEL_GPT = 'gpt-4o-mini'
MODEL_LLAMA = 'llama3.2'

# %%
# set up environment

load_dotenv(override=True)
api_key = os.getenv('OPENAI_API_KEY')

if api_key and api_key.startswith('sk-proj-') and len(api_key)>10:
    print("API key looks good so far")
else:
    print("There might be a problem with your API key? Please visit the troubleshooting notebook!")
    
openai = OpenAI()
# Out:
# API key looks good so far

# %%
# here is the question; type over this to ask something new
system_prompt =""" you are a helpful python tutor that helps me with coding and
understanding code with examples. When asked a technical question you will define it with an
example. """


user_prompt = """
Please explain what this code does and why:
yield from {book.get("author") for book in books if book.get("author")}
"""


messages = [{'role': 'system', 'content': system_prompt},
             {'role': 'user', 'content': user_prompt}]

# %%
# Get gpt-4o-mini to answer, with streaming
stream = openai.chat.completions.create(model = MODEL_GPT,
messages = messages, stream = True)
response = ""
for chunk in stream:
    response += chunk.choices[0].delta.content or ''
display(Markdown(response))
# Out:
# This line of code uses the `yield from` expression, which is part of Python's generator functionality. Let's break down what this code does step by step.
#
# ### Components of the Code
#
# 1. **`{book.get("author") for book in books if book.get("author")}`**:
#    - This is a set comprehension, which is a concise way to create a set in Python.
#    - It iterates through the `books` iterable (a list, for instance) and retrieves the value associated with the "author" key from each `book`.
#    - The condition `if book.get("author")` ensures that only books with a non-empty "author" value are considered.
#    - The result of this set comprehension is a set containing the unique authors of the books, ignoring any books that do not have an author.
#
# 2. **`yield from`**:
#    - This expression is used within a generator function. It yields all items from an iterable.
#    - When the generator is called, it will yield each item in the set created by the comprehension, one at a time.
#
# ...

# %%
# Get Llama 3.2 to answer
OLLAMA_BASE_URL = "http://localhost:11434/v1"

ollama = OpenAI(base_url= OLLAMA_BASE_URL, api_key= "ollama")
stream = ollama.chat.completions.create(model = MODEL_LLAMA,
messages = messages, stream = True)
response = ""

display_handel = display(Markdown(""), display_id= True)
for chunk in stream:
    response += chunk.choices[0].delta.content or ''
    
    update_display(Markdown(response), display_id= display_handel.display_id)
# Out:
# **Code Explanation**
#
# The given code is using a Python feature called **generator expressions** to extract author names from a list of dictionaries. Let's break it down:
#
# ```python
# # Assume `books` is an iterable (e.g., list or another iterator)
#
# # Dictionary with book data (example)
# book = {
#     "id": 1,
#     "title": "Book 1",
#     "author": "John Doe"
# }
#
# # Another example dictionary
# books = [
#     {"id": 2, "title": "Book 2", "author": "Jane Smith"},
#     {"id": 3, "title": "Book 3"}
# ]
# ```
#
# **Code Example**
#
# ```python
# def get_authors(books):
#     authors = {book.get("author") for book in books if book.get("author")}
#     return authors
#
# # Create an iterator with the desired authors
# from collections import deque as dq
# authors_queue = dq(book1["author"] for book1 in book2["authors"])
# ```
# Now, `yield from` is used here but we can't assign a result using that as it is not the right method.
#
#
# ...
